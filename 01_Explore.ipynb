# %% [markdown]
# # Explore data `slack_1`

# %%
from pathlib import Path
import pandas as pd
from typing import List

import utils
import config

# %%
df_files = utils.summarize_data_files(config.DATA_SLACK_1).sort_values(["filetype", "antigen"])
df_files
# Out:
#                                     filepath                     filename  \
# 8     data/slack_1/1ADQ_top_70000_corpus.csv    1ADQ_top_70000_corpus.csv
# 9     data/slack_1/1FBI_top_70000_corpus.csv    1FBI_top_70000_corpus.csv
# 5     data/slack_1/1H0D_top_70000_corpus.csv    1H0D_top_70000_corpus.csv
# 14    data/slack_1/1NSN_top_70000_corpus.csv    1NSN_top_70000_corpus.csv
# 12    data/slack_1/1OB1_top_70000_corpus.csv    1OB1_top_70000_corpus.csv
# 16    data/slack_1/1WEJ_top_70000_corpus.csv    1WEJ_top_70000_corpus.csv
# 10    data/slack_1/2YPV_top_70000_corpus.csv    2YPV_top_70000_corpus.csv
# 2     data/slack_1/3RAJ_top_70000_corpus.csv    3RAJ_top_70000_corpus.csv
# 0     data/slack_1/3VRL_top_70000_corpus.csv    3VRL_top_70000_corpus.csv
# 4     data/slack_1/5E94_top_70000_corpus.csv    5E94_top_70000_corpus.csv
# 15  data/slack_1/1ADQ_outputFeaturesFile.txt  1ADQ_outputFeaturesFile.txt
# 11  data/slack_1/1FBI_outputFeaturesFile.txt  1FBI_outputFeaturesFile.txt
# 6   data/slack_1/1H0D_outputFeaturesFile.txt  1H0D_outputFeaturesFile.txt
# 1   data/slack_1/1NSN_outputFeaturesFile.txt  1NSN_outputFeaturesFile.txt
# 13  data/slack_1/1OB1_outputFeaturesFile.txt  1OB1_outputFeaturesFile.txt
# 7   data/slack_1/1WEJ_outputFeaturesFile.txt  1WEJ_outputFeaturesFile.txt
# 17  data/slack_1/2YPV_outputFeaturesFile.txt  2YPV_outputFeaturesFile.txt
# 18  data/slack_1/3RAJ_outputFeaturesFile.txt  3RAJ_outputFeaturesFile.txt
# 3   data/slack_1/3VRL_outputFeaturesFile.txt  3VRL_outputFeaturesFile.txt
# 19  data/slack_1/5E94_outputFeaturesFile.txt  5E94_outputFeaturesFile.txt
#
#    filetype antigen  datatype
# 8       csv    1ADQ    corpus
# 9       csv    1FBI    corpus
# 5       csv    1H0D    corpus
# 14      csv    1NSN    corpus
# 12      csv    1OB1    corpus
# 16      csv    1WEJ    corpus
# 10      csv    2YPV    corpus
# 2       csv    3RAJ    corpus
# 0       csv    3VRL    corpus
# 4       csv    5E94    corpus
# 15      txt    1ADQ  features
# 11      txt    1FBI  features
# 6       txt    1H0D  features
# 1       txt    1NSN  features
# 13      txt    1OB1  features
# 7       txt    1WEJ  features
# 17      txt    2YPV  features
# 18      txt    3RAJ  features
# 3       txt    3VRL  features
# 19      txt    5E94  features

# %% [markdown]
# ## File format
#
# It looks like `features` files have more annotations for the data in `corpus` files.

# %%
ag_data = utils.AntigenData("3VRL", config.DATA_SLACK_1)
ag_data.df_c.head(2)
# Out:
#   ID_slide_Variant               CDR3  Best        Slide  Energy  \
# 0      1873658_06a  CARPENLLLLLWYFDVW  True  LLLLLWYFDVW -112.82
# 1      7116990_04a    CARGLLLLLWYFDVW  True  LLLLLWYFDVW -112.82
#
#            Structure               UID
# 0  137442-BRDSLLUDLS  3VRL_1873658_06a
# 1  137442-BRDSLLUDLS  3VRL_7116990_04a

# %% [markdown]
# ## Fetch global dataset from all antigens

# %%
df_global = pd.read_csv(config.DATA_SLACK_1_GLOBAL, sep='\t').iloc[:, 1:]
df_global
# Out:
#        ID_slide_Variant               CDR3  Best        Slide  Energy  \
# 0           1873658_06a  CARPENLLLLLWYFDVW  True  LLLLLWYFDVW -112.82
# 1           7116990_04a    CARGLLLLLWYFDVW  True  LLLLLWYFDVW -112.82
# 2           7147788_05a   CARGGLLLLLWYFDVW  True  LLLLLWYFDVW -112.82
# 3           4403113_04a    CARLLVWLLLFFDYW  True  LVWLLLFFDYW -112.67
# 4           1662693_03a     CARFLWLLWYFDVW  True  FLWLLWYFDVW -111.92
# ...                 ...                ...   ...          ...     ...
# 699995      5564830_02a   CAIGHFSTVDWYFDVW  True  IGHFSTVDWYF  -92.52
# 699996      2217831_00a  CALIPLIDYYGSSPCYW  True  CALIPLIDYYG  -92.52
# 699997      4076303_06a  CARHRDYSNIHWYFDVW  True  YSNIHWYFDVW  -92.52
# 699998      2481088_03a     CAREEVLLLGFAYW  True  EEVLLLGFAYW  -92.52
# 699999      3256243_00a       CASLPLLSMDYW  True  CASLPLLSMDY  -92.52
#
#                 Structure               UID antigen
# 0       137442-BRDSLLUDLS  3VRL_1873658_06a    3VRL
# 1       137442-BRDSLLUDLS  3VRL_7116990_04a    3VRL
# 2       137442-BRDSLLUDLS  3VRL_7147788_05a    3VRL
# 3       137442-BRDSLLUDLS  3VRL_4403113_04a    3VRL
# 4       137442-BRDSLLUDLS  3VRL_1662693_03a    3VRL
# ...                   ...               ...     ...
# 699995  149536-DUDDRDLRDU  1OB1_5564830_02a    1OB1
# 699996  149536-DUDDRDLRDU  1OB1_2217831_00a    1OB1
# 699997  137120-LUSLRDRDUD  1OB1_4076303_06a    1OB1
# 699998  153631-DRLUDLULLR  1OB1_2481088_03a    1OB1
# 699999  149536-DUDDRDLRDU  1OB1_3256243_00a    1OB1
#
# [700000 rows x 8 columns]
