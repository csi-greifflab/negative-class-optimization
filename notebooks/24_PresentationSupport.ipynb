# %% [markdown]
# # A notebook with some resources for presentations

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math


import torch
import torch.nn as nn
import torch.nn.functional as F


from NegativeClassOptimization import ml
from NegativeClassOptimization import config, utils
from NegativeClassOptimization import preprocessing

# %%
ag_pos = "3VRL"
ag_neg = "1NSN"

df = utils.load_global_dataframe()

# %%
df["Slide"].iloc[0]
# Out:
# 'AAFITTVGWYF'

# %%
m = preprocessing.onehot_encode("CTRWILYYRIF").reshape((11, 20))
m = pd.DataFrame(m, columns=config.AMINOACID_ALPHABET, index=range(1, 12))
sns.heatmap(
    m,
    cmap="Blues",
    cbar=False,
    annot=True,
)
# Out:
# <AxesSubplot: >
